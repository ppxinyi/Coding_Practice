# %% [markdown]
# # Python and Genetics: 3-Hour Beginner Practice (50 Questions)
#
#
# **Topics:** variables, strings, lists, dictionaries, conditionals, loops, functions, DNA, RNA, proteins, and mutations
#
# Run each cell with **Shift + Enter**. Complete every blank marked `_____`.
#
# > Biology note: The examples are simplified for learning and use short artificial sequences.

# %% [markdown]
# ## 1. Variables and DNA sequence length
#
# A DNA sequence can be stored as a Python string. Complete the code to print the sequence and its length.

# %%
dna = "ATGCGTACCA"

dna_length = _____

print("DNA:", dna)
print("Length:", dna_length)

# %% [markdown]
# ## 2. Accessing individual bases
#
# Python starts counting positions at zero. Complete the code to obtain the first and last bases.

# %%
dna = "ATGCGTACCA"

first_base = dna[_____]
last_base = dna[_____]

print("First base:", first_base)
print("Last base:", last_base)

# %% [markdown]
# ## 3. Counting nucleotides
#
# Use the string method `count()` to count each nucleotide.

# %%
dna = "AATGCCGTAAGC"

a_count = dna.count(_____)
t_count = dna.count(_____)
c_count = dna.count(_____)
g_count = dna.count(_____)

print("A:", a_count, "T:", t_count, "C:", c_count, "G:", g_count)

# %% [markdown]
# ## 4. Calculating GC content
#
# GC content is the percentage of bases that are G or C.
#
# `GC percentage = (number of G and C bases / sequence length) × 100`

# %%
dna = "AATGCCGTAAGC"

gc_count = dna.count(_____) + dna.count(_____)
gc_percent = _____ / _____ * 100

print(f"GC content: {gc_percent:.1f}%")

# %% [markdown]
# ## 5. Validating a DNA sequence
#
# A valid DNA sequence should contain only A, T, C, and G. Complete the condition.

# %%
dna = "ATGCBTA"
valid_bases = set("ATCG")

if set(dna).issubset(_____):
    print("Valid DNA sequence")
else:
    print("Invalid DNA sequence")

# %% [markdown]
# ## 6. Classifying a sequence by GC content
#
# Classify the DNA as high-GC when its GC content is at least 50%.

# %%
dna = "GCGCATTA"
gc_percent = (dna.count("G") + dna.count("C")) / len(dna) * 100

if gc_percent _____ 50:
    print("High-GC sequence")
else:
    print("Low-GC sequence")

# %% [markdown]
# ## 7. DNA transcription
#
# During transcription, T in the coding DNA strand is replaced by U in RNA. Complete the function.

# %%
def transcribe(dna):
    rna = dna._____(_____, _____)
    return rna

print(transcribe("ATGCCATAA"))

# %% [markdown]
# ## 8. Complementary DNA strand
#
# DNA base-pairing rules are A–T and C–G. Complete the dictionary and loop.

# %%
dna = "ATGCCA"
base_pairs = {"A": "T", "T": "A", "C": _____, "G": _____}
complement = ""

for base in _____:
    complement += base_pairs[_____]

print("DNA:       ", dna)
print("Complement:", complement)

# %% [markdown]
# ## 9. Reverse complement
#
# The reverse complement is the complementary sequence written in reverse order.

# %%
def reverse_complement(dna):
    base_pairs = {"A": "T", "T": "A", "C": "G", "G": "C"}
    complement = "".join(base_pairs[base] for base in dna)
    return complement[_____]

print(reverse_complement("ATGCCA"))

# %% [markdown]
# ## 10. Finding a start codon
#
# `ATG` is commonly used as a start codon. Find its zero-based position.

# %%
dna = "CCCGGATGAAACCC"

start_position = dna._____(_____)

print("ATG starts at Python index:", start_position)
print("ATG starts at biological position:", start_position + 1)

# %% [markdown]
# ## 11. Splitting a sequence into codons
#
# A codon contains three bases. Complete the loop to read the sequence three bases at a time.

# %%
dna = "ATGGCTTTCTAA"
codons = []

for i in range(0, len(dna), _____):
    codon = dna[i:i + _____]
    codons.append(codon)

print(codons)

# %% [markdown]
# ## 12. Translating codons into amino acids
#
# Use this small codon table to translate an artificial coding sequence. `*` represents a stop codon.

# %%
codon_table = {
    "ATG": "M", "GCT": "A", "TTC": "F", "TAA": "*"
}
dna = "ATGGCTTTCTAA"
protein = ""

for i in range(0, len(dna), 3):
    codon = dna[i:i + 3]
    protein += codon_table[_____]

print("Protein:", protein)

# %% [markdown]
# ## 13. Finding substitutions
#
# Compare equal-length sequences and report every substitution. Display positions starting at 1.

# %%
reference = "ATGCCGTA"
sample =    "ATGTCGAA"

for i in range(len(reference)):
    if reference[i] _____ sample[i]:
        print(
            "Position", _____,
            "changed from", reference[i],
            "to", sample[i]
        )

# %% [markdown]
# ## 14. Classifying a simple mutation
#
# For this simplified exercise, compare sequence lengths to classify an insertion, deletion, or substitution.

# %%
def classify_mutation(reference, sample):
    if len(sample) > len(reference):
        return "_____"
    elif len(sample) < len(reference):
        return "_____"
    elif sample != reference:
        return "_____"
    else:
        return "No mutation"

print(classify_mutation("ATGCCA", "ATGGCCA"))
print(classify_mutation("ATGCCA", "ATGCA"))
print(classify_mutation("ATGCCA", "ATGTCA"))

# %% [markdown]
# ## 15. Mini-project: DNA sequence report
#
# Complete a function that validates a sequence and reports its length, nucleotide counts, GC content, RNA sequence, and reverse complement.

# %%
def dna_report(sequence):
    dna = sequence._____()
    valid_bases = set("ATCG")

    if not set(dna).issubset(_____):
        return {"error": "Invalid DNA sequence"}

    gc_count = dna.count("G") + dna.count("C")
    gc_percent = _____
    rna = dna.replace(_____, _____)

    base_pairs = {"A": "T", "T": "A", "C": "G", "G": "C"}
    reverse_comp = "".join(base_pairs[b] for b in dna)[_____]

    return {
        "sequence": dna,
        "length": _____,
        "A": dna.count("A"),
        "T": dna.count("T"),
        "C": dna.count("C"),
        "G": dna.count("G"),
        "GC_percent": round(gc_percent, 1),
        "RNA": rna,
        "reverse_complement": reverse_comp,
    }

report = dna_report("atggctttctaa")
for key, value in report.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 16. Convert lowercase DNA to uppercase
#
# Use a string method to standardize the sequence.

# %%
dna = "atgccta"
clean_dna = dna._____()
print(clean_dna)

# %% [markdown]
# ## 17. Remove spaces from a sequence
#
# Remove spaces before analyzing the DNA.

# %%
dna = "ATG CCT AA"
clean_dna = dna._____(" ", "")
print(clean_dna)

# %% [markdown]
# ## 18. Join two DNA fragments
#
# Use the string concatenation operator.

# %%
fragment1 = "ATGC"
fragment2 = "CTAA"
full_sequence = fragment1 _____ fragment2
print(full_sequence)

# %% [markdown]
# ## 19. Extract the first codon
#
# Use slicing to obtain bases 1–3.

# %%
dna = "ATGGCCTAA"
first_codon = dna[_____:_____]
print(first_codon)

# %% [markdown]
# ## 20. Extract the last codon
#
# Use negative indexing to obtain the final three bases.

# %%
dna = "ATGGCCTAA"
last_codon = dna[_____]
print(last_codon)

# %% [markdown]
# ## 21. Test whether a sequence starts with ATG
#
# Use `startswith()`.

# %%
dna = "ATGGCCTAA"
if dna._____("ATG"):
    print("Start codon found")

# %% [markdown]
# ## 22. Test whether a sequence ends with a stop codon
#
# Check for the stop codon TAA.

# %%
dna = "ATGGCCTAA"
if dna._____("TAA"):
    print("Stop codon found")

# %% [markdown]
# ## 23. Count ATG codons
#
# Count how many times ATG appears.

# %%
dna = "ATGAAAATGCCCATG"
number_of_atg = dna._____(_____)
print(number_of_atg)

# %% [markdown]
# ## 24. Store several gene names
#
# Create a Python list.

# %%
genes = [_____, _____, _____]
print(genes)

# %% [markdown]
# ## 25. Select a gene from a list
#
# Select the second item from the list.

# %%
genes = ["TP53", "EGFR", "MYC"]
second_gene = genes[_____]
print(second_gene)

# %% [markdown]
# ## 26. Add a gene to a list
#
# Use `append()`.

# %%
genes = ["TP53", "EGFR"]
genes._____("MYC")
print(genes)

# %% [markdown]
# ## 27. Loop through gene names
#
# Print each gene on a separate line.

# %%
genes = ["TP53", "EGFR", "MYC"]
for gene in _____:
    print(_____)

# %% [markdown]
# ## 28. Store gene lengths in a dictionary
#
# Complete a dictionary and retrieve one value.

# %%
gene_lengths = {"TP53": 19149, "EGFR": _____}
print(gene_lengths[_____])

# %% [markdown]
# ## 29. Calculate an average gene length
#
# Use `sum()` and `len()`.

# %%
lengths = [1000, 1500, 2000]
average = _____ / _____
print(average)

# %% [markdown]
# ## 30. Find the longest sequence length
#
# Use Python's `max()` function.

# %%
lengths = [120, 95, 150, 108]
longest = _____(lengths)
print(longest)

# %% [markdown]
# ## 31. Find the shortest sequence length
#
# Use Python's `min()` function.

# %%
lengths = [120, 95, 150, 108]
shortest = _____(lengths)
print(shortest)

# %% [markdown]
# ## 32. Count sequences in a list
#
# Use `len()`.

# %%
sequences = ["ATGC", "GGTA", "CCAA", "TTGC"]
number = _____(sequences)
print(number)

# %% [markdown]
# ## 33. Print only long sequences
#
# Print sequences with at least six bases.

# %%
sequences = ["ATGC", "ATGCCA", "GG", "CCGTAAA"]
for seq in sequences:
    if len(seq) _____ 6:
        print(seq)

# %% [markdown]
# ## 34. Count valid sequences
#
# Increase a counter for every valid DNA sequence.

# %%
sequences = ["ATGC", "ATBX", "GGTA", "C123"]
valid = 0
for seq in sequences:
    if set(seq).issubset(set("ATCG")):
        valid _____ 1
print(valid)

# %% [markdown]
# ## 35. Make a function that counts A
#
# Return the number of A bases.

# %%
def count_a(dna):
    return dna._____("A")

print(count_a("AATGCA"))

# %% [markdown]
# ## 36. Make a function that calculates sequence length
#
# Return the length of a sequence.

# %%
def sequence_length(dna):
    return _____(dna)

print(sequence_length("ATGCCA"))

# %% [markdown]
# ## 37. Make a GC-count function
#
# Return the total number of G and C bases.

# %%
def gc_count(dna):
    return dna.count("G") _____ dna.count("C")

print(gc_count("GGATCC"))

# %% [markdown]
# ## 38. Detect an ATG start codon
#
# Return True when the sequence starts with ATG.

# %%
def has_start_codon(dna):
    return dna._____("ATG")

print(has_start_codon("ATGCCA"))

# %% [markdown]
# ## 39. Detect any common stop codon
#
# Check TAA, TAG, and TGA.

# %%
def has_stop_codon(dna):
    stop_codons = ("TAA", "TAG", "TGA")
    return dna.endswith(_____)

print(has_stop_codon("ATGCCCTGA"))

# %% [markdown]
# ## 40. Test whether length is divisible by three
#
# Use the remainder operator `%`.

# %%
dna = "ATGGCCTAA"
if len(dna) _____ 3 == 0:
    print("Complete codons")

# %% [markdown]
# ## 41. Number the codons
#
# Use `enumerate()` starting from 1.

# %%
codons = ["ATG", "GCC", "TAA"]
for number, codon in enumerate(codons, start=_____):
    print(number, codon)

# %% [markdown]
# ## 42. Convert RNA back to DNA
#
# Replace U with T.

# %%
rna = "AUGGCCUAA"
dna = rna._____(_____, _____)
print(dna)

# %% [markdown]
# ## 43. Compare two sequence lengths
#
# Report whether their lengths match.

# %%
seq1 = "ATGCCA"
seq2 = "ATGTTA"
if len(seq1) _____ len(seq2):
    print("Same length")

# %% [markdown]
# ## 44. Count mismatched bases
#
# Count positions at which two equal-length sequences differ.

# %%
seq1 = "ATGCCA"
seq2 = "ATGTTA"
mismatches = 0
for a, b in zip(seq1, seq2):
    if a _____ b:
        mismatches += 1
print(mismatches)

# %% [markdown]
# ## 45. Calculate percent identity
#
# Percent identity is matching positions divided by sequence length.

# %%
seq1 = "ATGCCA"
seq2 = "ATGTTA"
matches = sum(a == b for a, b in zip(seq1, seq2))
identity = matches / _____ * 100
print(f"{identity:.1f}%")

# %% [markdown]
# ## 46. Find all ATG positions
#
# Save the biological position of every ATG motif.

# %%
dna = "ATGAAAATGCCCATG"
positions = []
for i in range(len(dna) - 2):
    if dna[i:i + 3] == _____:
        positions.append(i + _____)
print(positions)

# %% [markdown]
# ## 47. Build a nucleotide-frequency dictionary
#
# Store the count of each nucleotide.

# %%
dna = "AATGCCGA"
frequencies = {}
for base in "ATCG":
    frequencies[base] = dna._____(base)
print(frequencies)

# %% [markdown]
# ## 48. Select high-GC sequences
#
# Add sequences with GC content above 50% to a new list.

# %%
sequences = ["ATAT", "GCGC", "ATGC", "GGCCAA"]
high_gc = []
for seq in sequences:
    gc = (seq.count("G") + seq.count("C")) / len(seq) * 100
    if gc _____ 50:
        high_gc.append(_____)
print(high_gc)

# %% [markdown]
# ## 49. Create a simple FASTA-style label
#
# Combine a greater-than sign, gene name, and sequence length.

# %%
gene = "TP53"
dna = "ATGCCATAA"
label = _____ + gene + "_length_" + str(_____(dna))
print(label)

# %% [markdown]
# ## 50. Mini-project: summarize several DNA sequences
#
# For each sequence, print its ID, length, GC percentage, and validity.

# %%
samples = {"sample_1": "ATGCCA", "sample_2": "GGCCAA", "sample_3": "ATBX"}
valid_bases = set("ATCG")

for sample_id, dna in samples._____():
    valid = set(dna).issubset(_____)
    if valid:
        gc = (dna.count("G") + dna.count("C")) / _____ * 100
        print(sample_id, "length =", len(dna), "GC =", round(gc, 1), "valid =", valid)
    else:
        print(sample_id, "valid =", _____)
